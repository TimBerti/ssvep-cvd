# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
w = 20
s = w * 250 / (2*np.pi*16.5)
M = 7000

wavelet = signal.morlet2(M, s, w)
plt.plot(np.real(wavelet)[3000:4000]);
